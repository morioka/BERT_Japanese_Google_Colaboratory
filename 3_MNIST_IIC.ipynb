# %% [markdown]
# <a href="https://colab.research.google.com/github/morioka/BERT_Japanese_Google_Colaboratory/blob/master/3_MNIST_IIC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # IIC：Invariant Information Clustering for Unsupervised Image Classification and Segmentation
#
# 参考：
# https://github.com/RuABraun/phone-clustering

# %%
# 乱数のシードを固定
import os
import random
import numpy as np
import torch

SEED_VALUE = 1234  # これはなんでも良い
os.environ['PYTHONHASHSEED'] = str(SEED_VALUE)
random.seed(SEED_VALUE)
np.random.seed(SEED_VALUE)
torch.manual_seed(SEED_VALUE)  # PyTorchを使う場合

# %%
# GPUが使えるときにはGPUに（Google Colaboratoryの場合はランタイムからGPUを指定）
device = 'cuda' if torch.cuda.is_available() else 'cpu'
print(device)  

# GPUを使用。cudaと出力されるのを確認する。
# Out:
# cuda

# %%
# MNISTの画像をダウンロードし、DataLoaderにする（TrainとTest）
from torchvision import datasets, transforms

batch_size_train = 512

train_loader = torch.utils.data.DataLoader(
    datasets.MNIST('.', train=True, download=True,
                   transform=transforms.Compose([
                       transforms.ToTensor(),
                   ])),
    batch_size=batch_size_train, shuffle=True, drop_last=True)
# drop_lastは最後のミニバッチが規定のサイズより小さい場合は使用しない設定


test_loader = torch.utils.data.DataLoader(
    datasets.MNIST('.', train=False, transform=transforms.Compose([
        transforms.ToTensor(),
    ])),
    batch_size=1024, shuffle=False)
# Out:
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz to ./MNIST/raw/train-images-idx3-ubyte.gz
# HBox(children=(FloatProgress(value=0.0, max=9912422.0), HTML(value='')))
# Extracting ./MNIST/raw/train-images-idx3-ubyte.gz to ./MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz to ./MNIST/raw/train-labels-idx1-ubyte.gz
# HBox(children=(FloatProgress(value=0.0, max=28881.0), HTML(value='')))
# Extracting ./MNIST/raw/train-labels-idx1-ubyte.gz to ./MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz to ./MNIST/raw/t10k-images-idx3-ubyte.gz
# Failed to download (trying next):
# HTTP Error 503: Service Unavailable
#
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-images-idx3-ubyte.gz
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-images-idx3-ubyte.gz to ./MNIST/raw/t10k-images-idx3-ubyte.gz
# HBox(children=(FloatProgress(value=0.0, max=1648877.0), HTML(value='')))
# Extracting ./MNIST/raw/t10k-images-idx3-ubyte.gz to ./MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz to ./MNIST/raw/t10k-labels-idx1-ubyte.gz
# HBox(children=(FloatProgress(value=0.0, max=4542.0), HTML(value='')))
# Extracting ./MNIST/raw/t10k-labels-idx1-ubyte.gz to ./MNIST/raw
#
# Processing...
# Done!
# /usr/local/lib/python3.7/dist-packages/torchvision/datasets/mnist.py:502: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /pytorch/torch/csrc/utils/tensor_numpy.cpp:143.)
#   return torch.from_numpy(parsed.astype(m[2], copy=False)).view(*s)

# %%
# ディープラーニングモデル
import torch.nn as nn
import torch.nn.functional as F

OVER_CLUSTRING_Rate = 10  # 多めに分類するoverclsuteringも用意する


class NetIIC(nn.Module):
    def __init__(self):
        super(NetIIC, self).__init__()

        self.conv1 = nn.Conv2d(1, 128, 5, 2, bias=False)
        self.bn1 = nn.BatchNorm2d(128)
        self.conv2 = nn.Conv2d(128, 128, 5, 1, bias=False)
        self.bn2 = nn.BatchNorm2d(128)
        self.conv3 = nn.Conv2d(128, 128, 5, 1, bias=False)
        self.bn3 = nn.BatchNorm2d(128)
        self.conv4 = nn.Conv2d(128, 256, 4, 1, bias=False)
        self.bn4 = nn.BatchNorm2d(256)
        
        # 0-9に対応すると期待したい10種類のクラス
        self.fc = nn.Linear(256, 10)

        # overclustering
        # 実際の想定よりも多めにクラスタリングさせることで、ネットワークで微細な変化を捉えられるようにする
        self.fc_overclustering = nn.Linear(256, 10*OVER_CLUSTRING_Rate)

    def forward(self, x):
        x = F.relu(self.bn1(self.conv1(x)))
        x = F.relu(self.bn2(self.conv2(x)))
        x = F.relu(self.bn3(self.conv3(x)))
        x = F.relu(self.bn4(self.conv4(x)))
        x_prefinal = x.view(x.size(0), -1)
        y = F.softmax(self.fc(x_prefinal), dim=1)

        y_overclustering = F.softmax(self.fc_overclustering(
            x_prefinal), dim=1)  # overclustering

        return y, y_overclustering

# %%
import torch.nn.init as init


def weight_init(m):
    """重み初期化"""
    if isinstance(m, nn.Conv2d):
        init.xavier_normal_(m.weight.data)
        if m.bias is not None:
            init.normal_(m.bias.data)
    elif isinstance(m, nn.BatchNorm2d):
        init.normal_(m.weight.data, mean=1, std=0.02)
        init.constant_(m.bias.data, 0)
    elif isinstance(m, nn.Linear):
        # Xavier
        #init.xavier_normal_(m.weight.data)

        # He 
        init.kaiming_normal_(m.weight.data)
        
        if m.bias is not None:
            init.normal_(m.bias.data)

# %%
# データにノイズを加える関数の定義
import torchvision as tv
import torchvision.transforms.functional as TF


def perturb_imagedata(x):
    y = x.clone()
    batch_size = x.size(0)

    # ランダムなアフィン変換を実施
    trans = tv.transforms.RandomAffine(15, (0.2, 0.2,), (0.2, 0.75,))
    for i in range(batch_size):
        y[i, 0] = TF.to_tensor(trans(TF.to_pil_image(y[i, 0])))

    # ノイズを加える
    noise = torch.randn(batch_size, 1, x.size(2), x.size(3))
    div = torch.randint(20, 30, (batch_size,),
                        dtype=torch.float32).view(batch_size, 1, 1, 1)
    y += noise / div

    return y

# %%
# IISによる損失関数の定義
# 参考：https://github.com/RuABraun/phone-clustering/blob/master/mnist_basic.py
import sys


def compute_joint(x_out, x_tf_out):

    # x_out、x_tf_outは torch.Size([512, 10])。この二つをかけ算して同時分布を求める、torch.Size([2048, 10, 10])にする。
    # torch.Size([512, 10, 1]) * torch.Size([512, 1, 10])
    p_i_j = x_out.unsqueeze(2) * x_tf_out.unsqueeze(1)
    # p_i_j は　torch.Size([512, 10, 10])

    # 全ミニバッチを足し算する ⇒ torch.Size([10, 10])
    p_i_j = p_i_j.sum(dim=0)

    # 転置行列と足し算して割り算（対称化） ⇒ torch.Size([10, 10])
    p_i_j = (p_i_j + p_i_j.t()) / 2.

    # 規格化 ⇒ torch.Size([10, 10])
    p_i_j = p_i_j / p_i_j.sum()

    return p_i_j
    # 結局、p_i_jは通常画像の判定出力10種類と、変換画像の判定10種類の100パターンに対して、全ミニバッチが100パターンのどれだったのかの確率分布表を示す


def IID_loss(x_out, x_tf_out, EPS=sys.float_info.epsilon):
    # torch.Size([512, 10])、後ろの10は分類数なので、overclusteringのときは100
    bs, k = x_out.size()
    p_i_j = compute_joint(x_out, x_tf_out)  # torch.Size([10, 10])

    # 同時確率の分布表から、変換画像の10パターンをsumをして周辺化し、元画像だけの周辺確率の分布表を作る
    p_i = p_i_j.sum(dim=1).view(k, 1).expand(k, k)
    # 同時確率の分布表から、元画像の10パターンをsumをして周辺化し、変換画像だけの周辺確率の分布表を作る
    p_j = p_i_j.sum(dim=0).view(1, k).expand(k, k)

    # 0に近い値をlogに入れると発散するので、避ける
    #p_i_j[(p_i_j < EPS).data] = EPS
    #p_j[(p_j < EPS).data] = EPS
    #p_i[(p_i < EPS).data] = EPS
    # 参考GitHubの実装（↑）は、PyTorchのバージョン1.3以上だとエラーになる
    # https://discuss.pytorch.org/t/pytorch-1-3-showing-an-error-perhaps-for-loss-computed-from-paired-outputs/68790/3

    # 0に近い値をlogに入れると発散するので、避ける
    p_i_j = torch.where(p_i_j < EPS, torch.tensor(
        [EPS], device=p_i_j.device), p_i_j)
    p_j = torch.where(p_j < EPS, torch.tensor([EPS], device=p_j.device), p_j)
    p_i = torch.where(p_i < EPS, torch.tensor([EPS], device=p_i.device), p_i)

    # 元画像、変換画像の同時確率と周辺確率から、相互情報量を計算
    # ただし、マイナスをかけて最小化問題にする
    """
    相互情報量を最大化したい
    ⇒結局、x_out, x_tf_outが持ちあう情報量が多くなって欲しい
    ⇒要は、x_out, x_tf_outが一緒になって欲しい

    p_i_jはx_out, x_tf_outの同時確率分布で、ミニバッチが極力、10×10のいろんなパターン、満遍なく一様が嬉しい
    
    前半の項、torch.log(p_i_j)はp_ijがどれも1に近いと大きな値（0に近い）になる。
    どれかが1であと0でバラついていないと、log0で小さな値（負の大きな値）になる
    つまり前半の項は、

    後半の項は、元画像、もしくは変換画像について、それぞれ周辺化して10通りのどれになるかを計算した項。
    周辺化した10×10のパターンを引き算して、前半の項が小さくなるのであれば、
    x_outとx_tf_outはあまり情報を共有していなかったことになる。
    """
    # https://qiita.com/Amanokawa/items/0aa24bc396dd88fb7d2a
    # を参考に、重みalphaを追加
    # 同時確率分布表のばらつきによる罰則を小さく ＝ 同時確率の分布がバラつきやすくする
    alpha = 2.0  # 論文や通常の相互情報量の計算はalphaは1です

    loss = -1*(p_i_j * (torch.log(p_i_j) - alpha *
                        torch.log(p_j) - alpha*torch.log(p_i))).sum()

    return loss

# %%
# 訓練の実施
total_epoch = 20


# モデル
model = NetIIC()
model.apply(weight_init)
model.to(device)

# 最適化関数を設定
optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)


def train(total_epoch, model, train_loader, optimizer, device):

    model.train()
    scheduler = torch.optim.lr_scheduler.CosineAnnealingWarmRestarts(
        optimizer, T_0=2, T_mult=2)

    for epoch in range(total_epoch):
        for batch_idx, (data, target) in enumerate(train_loader):

            # 学習率変化
            scheduler.step()

            # 微妙に変換したデータを作る。SIMULTANEOUS_NUM分のペアを作る
            data_perturb = perturb_imagedata(data)  # ノイズを与える

            # GPUに送れる場合は送る
            data = data.to(device)
            data_perturb = data_perturb.to(device)

            # 最適化関数の初期化
            optimizer.zero_grad()

            # ニューラルネットワーク出力
            output, output_overclustering = model(data)
            output_perturb, output_perturb_overclustering = model(data_perturb)

            # 損失の計算
            loss1 = IID_loss(output, output_perturb)
            loss2 = IID_loss(output_overclustering,
                             output_perturb_overclustering)
            loss = loss1 + loss2

            # 損失を減らすように更新
            loss.backward()
            optimizer.step()

            # ログ出力
            if batch_idx % 10 == 0:
                print('Train Epoch {}:iter{} - \tLoss1: {:.6f}- \tLoss2: {:.6f}- \tLoss_total: {:.6f}'.format(
                    epoch, batch_idx, loss1.item(), loss2.item(), loss1.item()+loss2.item()))

    return model, optimizer


model_trained, optimizer = train(
    total_epoch, model, train_loader, optimizer, device)
# Out:
# Train Epoch 0:iter0 - 	Loss1: -4.058846- 	Loss2: -7.889511- 	Loss_total: -11.948357
# Train Epoch 0:iter10 - 	Loss1: -4.617731- 	Loss2: -9.018221- 	Loss_total: -13.635952
# Train Epoch 0:iter20 - 	Loss1: -4.634532- 	Loss2: -9.191555- 	Loss_total: -13.826087
# Train Epoch 0:iter30 - 	Loss1: -4.651063- 	Loss2: -9.227157- 	Loss_total: -13.878220
# Train Epoch 0:iter40 - 	Loss1: -4.675164- 	Loss2: -9.236414- 	Loss_total: -13.911578
# Train Epoch 0:iter50 - 	Loss1: -4.696863- 	Loss2: -9.264532- 	Loss_total: -13.961395
# Train Epoch 0:iter60 - 	Loss1: -4.703871- 	Loss2: -9.273351- 	Loss_total: -13.977221
# Train Epoch 0:iter70 - 	Loss1: -4.824157- 	Loss2: -9.284760- 	Loss_total: -14.108917
# Train Epoch 0:iter80 - 	Loss1: -4.900006- 	Loss2: -9.363199- 	Loss_total: -14.263205
# Train Epoch 0:iter90 - 	Loss1: -5.025826- 	Loss2: -9.444096- 	Loss_total: -14.469922
# Train Epoch 0:iter100 - 	Loss1: -5.021190- 	Loss2: -9.495825- 	Loss_total: -14.517015
# Train Epoch 0:iter110 - 	Loss1: -5.087078- 	Loss2: -9.559996- 	Loss_total: -14.647073
# Train Epoch 1:iter0 - 	Loss1: -5.057349- 	Loss2: -9.538341- 	Loss_total: -14.595690
# Train Epoch 1:iter10 - 	Loss1: -5.032441- 	Loss2: -9.554228- 	Loss_total: -14.586669
# Train Epoch 1:iter20 - 	Loss1: -5.137352- 	Loss2: -9.763162- 	Loss_total: -14.900514
# Train Epoch 1:iter30 - 	Loss1: -5.224974- 	Loss2: -9.883937- 	Loss_total: -15.108911
# Train Epoch 1:iter40 - 	Loss1: -5.264894- 	Loss2: -9.963291- 	Loss_total: -15.228186
# Train Epoch 1:iter50 - 	Loss1: -5.272587- 	Loss2: -10.011265- 	Loss_total: -15.283852
# Train Epoch 1:iter60 - 	Loss1: -5.296837- 	Loss2: -10.171747- 	Loss_total: -15.468584
# Train Epoch 1:iter70 - 	Loss1: -5.453786- 	Loss2: -10.335270- 	Loss_total: -15.789056
# Train Epoch 1:iter80 - 	Loss1: -5.437961- 	Loss2: -10.316263- 	Loss_total: -15.754224
# Train Epoch 1:iter90 - 	Loss1: -5.504716- 	Loss2: -10.433701- 	Loss_total: -15.938417
# Train Epoch 1:iter100 - 	Loss1: -5.445609- 	Loss2: -10.463982- 	Loss_total: -15.909591
# Train Epoch 1:iter110 - 	Loss1: -5.531613- 	Loss2: -10.519020- 	Loss_total: -16.050633
# Train Epoch 2:iter0 - 	Loss1: -5.497529- 	Loss2: -10.528425- 	Loss_total: -16.025954
# Train Epoch 2:iter10 - 	Loss1: -5.513049- 	Loss2: -10.508657- 	Loss_total: -16.021707
# Train Epoch 2:iter20 - 	Loss1: -5.451866- 	Loss2: -10.453191- 	Loss_total: -15.905057
# Train Epoch 2:iter30 - 	Loss1: -5.474173- 	Loss2: -10.624182- 	Loss_total: -16.098354
# Train Epoch 2:iter40 - 	Loss1: -5.424405- 	Loss2: -10.593351- 	Loss_total: -16.017756
# Train Epoch 2:iter50 - 	Loss1: -5.506763- 	Loss2: -10.797598- 	Loss_total: -16.304361
# Train Epoch 2:iter60 - 	Loss1: -5.654140- 	Loss2: -10.968372- 	Loss_total: -16.622512
# Train Epoch 2:iter70 - 	Loss1: -5.631413- 	Loss2: -11.117867- 	Loss_total: -16.749279
# Train Epoch 2:iter80 - 	Loss1: -5.651926- 	Loss2: -11.178768- 	Loss_total: -16.830694
# Train Epoch 2:iter90 - 	Loss1: -5.749882- 	Loss2: -11.359170- 	Loss_total: -17.109052
# Train Epoch 2:iter100 - 	Loss1: -5.710152- 	Loss2: -11.332876- 	Loss_total: -17.043028
# Train Epoch 2:iter110 - 	Loss1: -5.718591- 	Loss2: -11.388760- 	Loss_total: -17.107350
# Train Epoch 3:iter0 - 	Loss1: -5.728295- 	Loss2: -11.439487- 	Loss_total: -17.167783
# Train Epoch 3:iter10 - 	Loss1: -5.831762- 	Loss2: -11.468039- 	Loss_total: -17.299801
# Train Epoch 3:iter20 - 	Loss1: -5.816167- 	Loss2: -11.480692- 	Loss_total: -17.296859
# Train Epoch 3:iter30 - 	Loss1: -5.855953- 	Loss2: -11.465336- 	Loss_total: -17.321289
# Train Epoch 3:iter40 - 	Loss1: -5.844325- 	Loss2: -11.619081- 	Loss_total: -17.463407
# Train Epoch 3:iter50 - 	Loss1: -5.855531- 	Loss2: -11.577679- 	Loss_total: -17.433209
# Train Epoch 3:iter60 - 	Loss1: -5.925269- 	Loss2: -11.613832- 	Loss_total: -17.539100
# Train Epoch 3:iter70 - 	Loss1: -5.896903- 	Loss2: -11.620409- 	Loss_total: -17.517312
# Train Epoch 3:iter80 - 	Loss1: -5.885564- 	Loss2: -11.607378- 	Loss_total: -17.492942
# Train Epoch 3:iter90 - 	Loss1: -5.969350- 	Loss2: -11.668772- 	Loss_total: -17.638122
# Train Epoch 3:iter100 - 	Loss1: -5.910351- 	Loss2: -11.705478- 	Loss_total: -17.615829
# Train Epoch 3:iter110 - 	Loss1: -5.959305- 	Loss2: -11.679662- 	Loss_total: -17.638967
# Train Epoch 4:iter0 - 	Loss1: -5.959484- 	Loss2: -11.663256- 	Loss_total: -17.622740
# Train Epoch 4:iter10 - 	Loss1: -5.954550- 	Loss2: -11.655004- 	Loss_total: -17.609553
# Train Epoch 4:iter20 - 	Loss1: -5.949263- 	Loss2: -11.661819- 	Loss_total: -17.611082
# Train Epoch 4:iter30 - 	Loss1: -5.976103- 	Loss2: -11.713614- 	Loss_total: -17.689716
# Train Epoch 4:iter40 - 	Loss1: -5.893218- 	Loss2: -11.590699- 	Loss_total: -17.483917
# Train Epoch 4:iter50 - 	Loss1: -5.866671- 	Loss2: -11.637465- 	Loss_total: -17.504137
# Train Epoch 4:iter60 - 	Loss1: -5.860922- 	Loss2: -11.546455- 	Loss_total: -17.407377
# Train Epoch 4:iter70 - 	Loss1: -5.906842- 	Loss2: -11.631863- 	Loss_total: -17.538705
# Train Epoch 4:iter80 - 	Loss1: -5.829130- 	Loss2: -11.523836- 	Loss_total: -17.352966
# Train Epoch 4:iter90 - 	Loss1: -5.939168- 	Loss2: -11.679993- 	Loss_total: -17.619161
# Train Epoch 4:iter100 - 	Loss1: -5.927122- 	Loss2: -11.723983- 	Loss_total: -17.651104
# Train Epoch 4:iter110 - 	Loss1: -5.902611- 	Loss2: -11.674179- 	Loss_total: -17.576790
# Train Epoch 5:iter0 - 	Loss1: -5.998522- 	Loss2: -11.756485- 	Loss_total: -17.755007
# Train Epoch 5:iter10 - 	Loss1: -5.951930- 	Loss2: -11.718017- 	Loss_total: -17.669947
# Train Epoch 5:iter20 - 	Loss1: -5.996009- 	Loss2: -11.817944- 	Loss_total: -17.813952
# Train Epoch 5:iter30 - 	Loss1: -6.009269- 	Loss2: -11.835232- 	Loss_total: -17.844501
# Train Epoch 5:iter40 - 	Loss1: -5.988647- 	Loss2: -11.820704- 	Loss_total: -17.809350
# Train Epoch 5:iter50 - 	Loss1: -5.884125- 	Loss2: -11.807560- 	Loss_total: -17.691685
# Train Epoch 5:iter60 - 	Loss1: -5.968869- 	Loss2: -11.829288- 	Loss_total: -17.798158
# Train Epoch 5:iter70 - 	Loss1: -5.926591- 	Loss2: -11.764164- 	Loss_total: -17.690755
# Train Epoch 5:iter80 - 	Loss1: -5.916446- 	Loss2: -11.845791- 	Loss_total: -17.762237
# Train Epoch 5:iter90 - 	Loss1: -5.956676- 	Loss2: -11.838820- 	Loss_total: -17.795495
# Train Epoch 5:iter100 - 	Loss1: -5.973532- 	Loss2: -11.871037- 	Loss_total: -17.844570
# Train Epoch 5:iter110 - 	Loss1: -5.969522- 	Loss2: -11.844118- 	Loss_total: -17.813641
# Train Epoch 6:iter0 - 	Loss1: -6.049706- 	Loss2: -11.894707- 	Loss_total: -17.944413
# Train Epoch 6:iter10 - 	Loss1: -5.997923- 	Loss2: -11.888828- 	Loss_total: -17.886751
# Train Epoch 6:iter20 - 	Loss1: -6.057385- 	Loss2: -11.897430- 	Loss_total: -17.954816
# Train Epoch 6:iter30 - 	Loss1: -6.080134- 	Loss2: -11.873384- 	Loss_total: -17.953519
# Train Epoch 6:iter40 - 	Loss1: -6.009048- 	Loss2: -11.912617- 	Loss_total: -17.921665
# Train Epoch 6:iter50 - 	Loss1: -6.061834- 	Loss2: -11.920269- 	Loss_total: -17.982103
# Train Epoch 6:iter60 - 	Loss1: -6.157611- 	Loss2: -11.903248- 	Loss_total: -18.060859
# Train Epoch 6:iter70 - 	Loss1: -6.096196- 	Loss2: -11.964218- 	Loss_total: -18.060414
# Train Epoch 6:iter80 - 	Loss1: -6.029999- 	Loss2: -11.932323- 	Loss_total: -17.962323
# Train Epoch 6:iter90 - 	Loss1: -6.090580- 	Loss2: -11.913645- 	Loss_total: -18.004225
# Train Epoch 6:iter100 - 	Loss1: -6.161827- 	Loss2: -12.043724- 	Loss_total: -18.205551
# Train Epoch 6:iter110 - 	Loss1: -6.247957- 	Loss2: -12.006518- 	Loss_total: -18.254476
# Train Epoch 7:iter0 - 	Loss1: -6.118848- 	Loss2: -12.010218- 	Loss_total: -18.129066
# Train Epoch 7:iter10 - 	Loss1: -6.118459- 	Loss2: -11.936104- 	Loss_total: -18.054563
# Train Epoch 7:iter20 - 	Loss1: -6.222625- 	Loss2: -12.030901- 	Loss_total: -18.253526
# Train Epoch 7:iter30 - 	Loss1: -6.198637- 	Loss2: -11.997038- 	Loss_total: -18.195675
# Train Epoch 7:iter40 - 	Loss1: -6.074821- 	Loss2: -12.032831- 	Loss_total: -18.107652
# Train Epoch 7:iter50 - 	Loss1: -6.149444- 	Loss2: -12.020723- 	Loss_total: -18.170167
# Train Epoch 7:iter60 - 	Loss1: -6.145272- 	Loss2: -11.989429- 	Loss_total: -18.134702
# Train Epoch 7:iter70 - 	Loss1: -6.226380- 	Loss2: -11.974792- 	Loss_total: -18.201173
# Train Epoch 7:iter80 - 	Loss1: -6.226970- 	Loss2: -12.023024- 	Loss_total: -18.249994
# Train Epoch 7:iter90 - 	Loss1: -6.071323- 	Loss2: -11.970802- 	Loss_total: -18.042125
# Train Epoch 7:iter100 - 	Loss1: -6.109811- 	Loss2: -11.964290- 	Loss_total: -18.074101
# Train Epoch 7:iter110 - 	Loss1: -6.218309- 	Loss2: -12.093143- 	Loss_total: -18.311451
# Train Epoch 8:iter0 - 	Loss1: -6.183890- 	Loss2: -12.004112- 	Loss_total: -18.188003
# Train Epoch 8:iter10 - 	Loss1: -6.171152- 	Loss2: -11.978407- 	Loss_total: -18.149559
# Train Epoch 8:iter20 - 	Loss1: -6.219220- 	Loss2: -12.077327- 	Loss_total: -18.296546
# Train Epoch 8:iter30 - 	Loss1: -6.172360- 	Loss2: -12.063815- 	Loss_total: -18.236176
# Train Epoch 8:iter40 - 	Loss1: -6.220202- 	Loss2: -12.054762- 	Loss_total: -18.274964
# Train Epoch 8:iter50 - 	Loss1: -6.245516- 	Loss2: -12.004721- 	Loss_total: -18.250237
# Train Epoch 8:iter60 - 	Loss1: -6.236345- 	Loss2: -11.993325- 	Loss_total: -18.229670
# Train Epoch 8:iter70 - 	Loss1: -6.287987- 	Loss2: -12.111348- 	Loss_total: -18.399335
# Train Epoch 8:iter80 - 	Loss1: -6.294893- 	Loss2: -12.018044- 	Loss_total: -18.312937
# Train Epoch 8:iter90 - 	Loss1: -6.181137- 	Loss2: -11.969251- 	Loss_total: -18.150388
# Train Epoch 8:iter100 - 	Loss1: -6.125134- 	Loss2: -11.898997- 	Loss_total: -18.024132
# Train Epoch 8:iter110 - 	Loss1: -6.181734- 	Loss2: -11.987397- 	Loss_total: -18.169131
# Train Epoch 9:iter0 - 	Loss1: -6.206187- 	Loss2: -11.975046- 	Loss_total: -18.181233
# Train Epoch 9:iter10 - 	Loss1: -6.078344- 	Loss2: -12.026495- 	Loss_total: -18.104839
# Train Epoch 9:iter20 - 	Loss1: -6.169576- 	Loss2: -11.982530- 	Loss_total: -18.152105
# Train Epoch 9:iter30 - 	Loss1: -6.156725- 	Loss2: -12.096907- 	Loss_total: -18.253632
# Train Epoch 9:iter40 - 	Loss1: -6.080369- 	Loss2: -11.955789- 	Loss_total: -18.036158
# Train Epoch 9:iter50 - 	Loss1: -6.205858- 	Loss2: -12.023274- 	Loss_total: -18.229133
# Train Epoch 9:iter60 - 	Loss1: -6.151299- 	Loss2: -11.956789- 	Loss_total: -18.108088
# Train Epoch 9:iter70 - 	Loss1: -6.067404- 	Loss2: -12.010023- 	Loss_total: -18.077427
# Train Epoch 9:iter80 - 	Loss1: -6.131667- 	Loss2: -12.030638- 	Loss_total: -18.162305
# Train Epoch 9:iter90 - 	Loss1: -6.165177- 	Loss2: -12.018442- 	Loss_total: -18.183619
# Train Epoch 9:iter100 - 	Loss1: -6.144084- 	Loss2: -12.039687- 	Loss_total: -18.183771
# Train Epoch 9:iter110 - 	Loss1: -6.176287- 	Loss2: -12.066317- 	Loss_total: -18.242604
# Train Epoch 10:iter0 - 	Loss1: -6.195453- 	Loss2: -11.992950- 	Loss_total: -18.188403
# Train Epoch 10:iter10 - 	Loss1: -6.201525- 	Loss2: -12.044537- 	Loss_total: -18.246062
# Train Epoch 10:iter20 - 	Loss1: -6.082240- 	Loss2: -11.984171- 	Loss_total: -18.066411
# Train Epoch 10:iter30 - 	Loss1: -6.169529- 	Loss2: -12.027412- 	Loss_total: -18.196941
# Train Epoch 10:iter40 - 	Loss1: -6.134974- 	Loss2: -12.053103- 	Loss_total: -18.188077
# Train Epoch 10:iter50 - 	Loss1: -6.191721- 	Loss2: -12.032085- 	Loss_total: -18.223806
# Train Epoch 10:iter60 - 	Loss1: -6.235713- 	Loss2: -12.080351- 	Loss_total: -18.316064
# Train Epoch 10:iter70 - 	Loss1: -6.147256- 	Loss2: -12.031456- 	Loss_total: -18.178712
# Train Epoch 10:iter80 - 	Loss1: -6.243401- 	Loss2: -12.023182- 	Loss_total: -18.266582
# Train Epoch 10:iter90 - 	Loss1: -6.175685- 	Loss2: -12.083319- 	Loss_total: -18.259004
# Train Epoch 10:iter100 - 	Loss1: -6.231084- 	Loss2: -12.088478- 	Loss_total: -18.319562
# Train Epoch 10:iter110 - 	Loss1: -6.233646- 	Loss2: -12.115128- 	Loss_total: -18.348774
# Train Epoch 11:iter0 - 	Loss1: -6.263632- 	Loss2: -12.076723- 	Loss_total: -18.340355
# Train Epoch 11:iter10 - 	Loss1: -6.245854- 	Loss2: -12.083158- 	Loss_total: -18.329013
# Train Epoch 11:iter20 - 	Loss1: -6.299406- 	Loss2: -12.088465- 	Loss_total: -18.387871
# Train Epoch 11:iter30 - 	Loss1: -6.298749- 	Loss2: -12.089419- 	Loss_total: -18.388168
# Train Epoch 11:iter40 - 	Loss1: -6.254572- 	Loss2: -12.079480- 	Loss_total: -18.334052
# Train Epoch 11:iter50 - 	Loss1: -6.163194- 	Loss2: -12.073545- 	Loss_total: -18.236739
# Train Epoch 11:iter60 - 	Loss1: -6.149786- 	Loss2: -12.080207- 	Loss_total: -18.229993
# Train Epoch 11:iter70 - 	Loss1: -6.232985- 	Loss2: -12.112471- 	Loss_total: -18.345456
# Train Epoch 11:iter80 - 	Loss1: -6.222962- 	Loss2: -12.146297- 	Loss_total: -18.369260
# Train Epoch 11:iter90 - 	Loss1: -6.223781- 	Loss2: -12.090873- 	Loss_total: -18.314653
# Train Epoch 11:iter100 - 	Loss1: -6.269848- 	Loss2: -12.177210- 	Loss_total: -18.447058
# Train Epoch 11:iter110 - 	Loss1: -6.211505- 	Loss2: -12.088417- 	Loss_total: -18.299922
# Train Epoch 12:iter0 - 	Loss1: -6.243811- 	Loss2: -12.153040- 	Loss_total: -18.396851
# Train Epoch 12:iter10 - 	Loss1: -6.233278- 	Loss2: -12.086798- 	Loss_total: -18.320076
# Train Epoch 12:iter20 - 	Loss1: -6.258096- 	Loss2: -12.141550- 	Loss_total: -18.399646
# Train Epoch 12:iter30 - 	Loss1: -6.279636- 	Loss2: -12.181452- 	Loss_total: -18.461088
# Train Epoch 12:iter40 - 	Loss1: -6.371354- 	Loss2: -12.200644- 	Loss_total: -18.571997
# Train Epoch 12:iter50 - 	Loss1: -6.332868- 	Loss2: -12.176611- 	Loss_total: -18.509479
# Train Epoch 12:iter60 - 	Loss1: -6.293852- 	Loss2: -12.179292- 	Loss_total: -18.473144
# Train Epoch 12:iter70 - 	Loss1: -6.346820- 	Loss2: -12.194216- 	Loss_total: -18.541036
# Train Epoch 12:iter80 - 	Loss1: -6.326087- 	Loss2: -12.223431- 	Loss_total: -18.549518
# Train Epoch 12:iter90 - 	Loss1: -6.344591- 	Loss2: -12.202285- 	Loss_total: -18.546876
# Train Epoch 12:iter100 - 	Loss1: -6.332008- 	Loss2: -12.195134- 	Loss_total: -18.527143
# Train Epoch 12:iter110 - 	Loss1: -6.361084- 	Loss2: -12.158390- 	Loss_total: -18.519475
# Train Epoch 13:iter0 - 	Loss1: -6.304010- 	Loss2: -12.125662- 	Loss_total: -18.429672
# Train Epoch 13:iter10 - 	Loss1: -6.387424- 	Loss2: -12.221510- 	Loss_total: -18.608934
# Train Epoch 13:iter20 - 	Loss1: -6.257041- 	Loss2: -12.168879- 	Loss_total: -18.425920
# Train Epoch 13:iter30 - 	Loss1: -6.299487- 	Loss2: -12.186948- 	Loss_total: -18.486435
# Train Epoch 13:iter40 - 	Loss1: -6.372736- 	Loss2: -12.193210- 	Loss_total: -18.565946
# Train Epoch 13:iter50 - 	Loss1: -6.307864- 	Loss2: -12.206055- 	Loss_total: -18.513919
# Train Epoch 13:iter60 - 	Loss1: -6.327201- 	Loss2: -12.181002- 	Loss_total: -18.508203
# Train Epoch 13:iter70 - 	Loss1: -6.278796- 	Loss2: -12.158601- 	Loss_total: -18.437397
# Train Epoch 13:iter80 - 	Loss1: -6.220509- 	Loss2: -12.125641- 	Loss_total: -18.346149
# Train Epoch 13:iter90 - 	Loss1: -6.287345- 	Loss2: -12.203373- 	Loss_total: -18.490718
# Train Epoch 13:iter100 - 	Loss1: -6.259561- 	Loss2: -12.194300- 	Loss_total: -18.453860
# Train Epoch 13:iter110 - 	Loss1: -6.394751- 	Loss2: -12.229336- 	Loss_total: -18.624087
# Train Epoch 14:iter0 - 	Loss1: -6.382616- 	Loss2: -12.246343- 	Loss_total: -18.628959
# Train Epoch 14:iter10 - 	Loss1: -6.309052- 	Loss2: -12.266430- 	Loss_total: -18.575482
# Train Epoch 14:iter20 - 	Loss1: -6.396567- 	Loss2: -12.196646- 	Loss_total: -18.593213
# Train Epoch 14:iter30 - 	Loss1: -6.353334- 	Loss2: -12.250755- 	Loss_total: -18.604089
# Train Epoch 14:iter40 - 	Loss1: -6.368927- 	Loss2: -12.232648- 	Loss_total: -18.601575
# Train Epoch 14:iter50 - 	Loss1: -6.419311- 	Loss2: -12.188170- 	Loss_total: -18.607481
# Train Epoch 14:iter60 - 	Loss1: -6.384259- 	Loss2: -12.225023- 	Loss_total: -18.609282
# Train Epoch 14:iter70 - 	Loss1: -6.232063- 	Loss2: -12.225464- 	Loss_total: -18.457527
# Train Epoch 14:iter80 - 	Loss1: -6.371934- 	Loss2: -12.234652- 	Loss_total: -18.606586
# Train Epoch 14:iter90 - 	Loss1: -6.408760- 	Loss2: -12.237179- 	Loss_total: -18.645938
# Train Epoch 14:iter100 - 	Loss1: -6.395463- 	Loss2: -12.281173- 	Loss_total: -18.676635
# Train Epoch 14:iter110 - 	Loss1: -6.362350- 	Loss2: -12.260965- 	Loss_total: -18.623316
# Train Epoch 15:iter0 - 	Loss1: -6.294489- 	Loss2: -12.224949- 	Loss_total: -18.519438
# Train Epoch 15:iter10 - 	Loss1: -6.374796- 	Loss2: -12.239962- 	Loss_total: -18.614758
# Train Epoch 15:iter20 - 	Loss1: -6.328177- 	Loss2: -12.257304- 	Loss_total: -18.585482
# Train Epoch 15:iter30 - 	Loss1: -6.400910- 	Loss2: -12.293554- 	Loss_total: -18.694464
# Train Epoch 15:iter40 - 	Loss1: -6.452195- 	Loss2: -12.312188- 	Loss_total: -18.764383
# Train Epoch 15:iter50 - 	Loss1: -6.294671- 	Loss2: -12.298004- 	Loss_total: -18.592675
# Train Epoch 15:iter60 - 	Loss1: -6.381052- 	Loss2: -12.259098- 	Loss_total: -18.640150
# Train Epoch 15:iter70 - 	Loss1: -6.383829- 	Loss2: -12.253487- 	Loss_total: -18.637316
# Train Epoch 15:iter80 - 	Loss1: -6.440361- 	Loss2: -12.285540- 	Loss_total: -18.725901
# Train Epoch 15:iter90 - 	Loss1: -6.340694- 	Loss2: -12.262265- 	Loss_total: -18.602960
# Train Epoch 15:iter100 - 	Loss1: -6.379694- 	Loss2: -12.315685- 	Loss_total: -18.695379
# Train Epoch 15:iter110 - 	Loss1: -6.342321- 	Loss2: -12.182266- 	Loss_total: -18.524587
# Train Epoch 16:iter0 - 	Loss1: -6.344573- 	Loss2: -12.220434- 	Loss_total: -18.565008
# Train Epoch 16:iter10 - 	Loss1: -6.385630- 	Loss2: -12.255426- 	Loss_total: -18.641056
# Train Epoch 16:iter20 - 	Loss1: -6.460987- 	Loss2: -12.321349- 	Loss_total: -18.782336
# Train Epoch 16:iter30 - 	Loss1: -6.351520- 	Loss2: -12.287088- 	Loss_total: -18.638608
# Train Epoch 16:iter40 - 	Loss1: -6.363477- 	Loss2: -12.273810- 	Loss_total: -18.637287
# Train Epoch 16:iter50 - 	Loss1: -6.301843- 	Loss2: -12.168859- 	Loss_total: -18.470702
# Train Epoch 16:iter60 - 	Loss1: -6.359030- 	Loss2: -12.250799- 	Loss_total: -18.609829
# Train Epoch 16:iter70 - 	Loss1: -6.377680- 	Loss2: -12.283113- 	Loss_total: -18.660794
# Train Epoch 16:iter80 - 	Loss1: -6.362659- 	Loss2: -12.197943- 	Loss_total: -18.560602
# Train Epoch 16:iter90 - 	Loss1: -6.361093- 	Loss2: -12.237758- 	Loss_total: -18.598850
# Train Epoch 16:iter100 - 	Loss1: -6.432299- 	Loss2: -12.278308- 	Loss_total: -18.710607
# Train Epoch 16:iter110 - 	Loss1: -6.426322- 	Loss2: -12.234184- 	Loss_total: -18.660506
# Train Epoch 17:iter0 - 	Loss1: -6.348286- 	Loss2: -12.264370- 	Loss_total: -18.612656
# Train Epoch 17:iter10 - 	Loss1: -6.310540- 	Loss2: -12.232444- 	Loss_total: -18.542984
# Train Epoch 17:iter20 - 	Loss1: -6.326942- 	Loss2: -12.193229- 	Loss_total: -18.520171
# Train Epoch 17:iter30 - 	Loss1: -6.328485- 	Loss2: -12.249529- 	Loss_total: -18.578014
# Train Epoch 17:iter40 - 	Loss1: -6.372733- 	Loss2: -12.305097- 	Loss_total: -18.677830
# Train Epoch 17:iter50 - 	Loss1: -6.344141- 	Loss2: -12.243879- 	Loss_total: -18.588020
# Train Epoch 17:iter60 - 	Loss1: -6.338250- 	Loss2: -12.255795- 	Loss_total: -18.594045
# Train Epoch 17:iter70 - 	Loss1: -6.314111- 	Loss2: -12.147609- 	Loss_total: -18.461720
# Train Epoch 17:iter80 - 	Loss1: -6.212851- 	Loss2: -12.135626- 	Loss_total: -18.348476
# Train Epoch 17:iter90 - 	Loss1: -6.277605- 	Loss2: -12.149071- 	Loss_total: -18.426676
# Train Epoch 17:iter100 - 	Loss1: -6.246267- 	Loss2: -12.159522- 	Loss_total: -18.405789
# Train Epoch 17:iter110 - 	Loss1: -6.144858- 	Loss2: -12.062439- 	Loss_total: -18.207297
# Train Epoch 18:iter0 - 	Loss1: -6.299754- 	Loss2: -12.158445- 	Loss_total: -18.458200
# Train Epoch 18:iter10 - 	Loss1: -6.281919- 	Loss2: -12.168444- 	Loss_total: -18.450362
# Train Epoch 18:iter20 - 	Loss1: -6.349833- 	Loss2: -12.213152- 	Loss_total: -18.562985
# Train Epoch 18:iter30 - 	Loss1: -6.287822- 	Loss2: -12.205033- 	Loss_total: -18.492855
# Train Epoch 18:iter40 - 	Loss1: -6.350860- 	Loss2: -12.198701- 	Loss_total: -18.549561
# Train Epoch 18:iter50 - 	Loss1: -6.345192- 	Loss2: -12.263071- 	Loss_total: -18.608263
# Train Epoch 18:iter60 - 	Loss1: -6.218940- 	Loss2: -12.182262- 	Loss_total: -18.401202
# Train Epoch 18:iter70 - 	Loss1: -6.356387- 	Loss2: -12.202782- 	Loss_total: -18.559169
# Train Epoch 18:iter80 - 	Loss1: -6.307051- 	Loss2: -12.191525- 	Loss_total: -18.498576
# Train Epoch 18:iter90 - 	Loss1: -6.352911- 	Loss2: -12.233374- 	Loss_total: -18.586285
# Train Epoch 18:iter100 - 	Loss1: -6.181571- 	Loss2: -12.144993- 	Loss_total: -18.326563
# Train Epoch 18:iter110 - 	Loss1: -6.297294- 	Loss2: -12.157634- 	Loss_total: -18.454927
# Train Epoch 19:iter0 - 	Loss1: -6.217040- 	Loss2: -12.205931- 	Loss_total: -18.422971
# Train Epoch 19:iter10 - 	Loss1: -6.251759- 	Loss2: -12.195380- 	Loss_total: -18.447139
# Train Epoch 19:iter20 - 	Loss1: -6.340793- 	Loss2: -12.273262- 	Loss_total: -18.614055
# Train Epoch 19:iter30 - 	Loss1: -6.360949- 	Loss2: -12.277164- 	Loss_total: -18.638112
# Train Epoch 19:iter40 - 	Loss1: -6.354286- 	Loss2: -12.219501- 	Loss_total: -18.573787
# Train Epoch 19:iter50 - 	Loss1: -6.314603- 	Loss2: -12.199904- 	Loss_total: -18.514507
# Train Epoch 19:iter60 - 	Loss1: -6.216268- 	Loss2: -12.266893- 	Loss_total: -18.483161
# Train Epoch 19:iter70 - 	Loss1: -6.295021- 	Loss2: -12.144055- 	Loss_total: -18.439076
# Train Epoch 19:iter80 - 	Loss1: -6.227793- 	Loss2: -12.164898- 	Loss_total: -18.392691
# Train Epoch 19:iter90 - 	Loss1: -6.217416- 	Loss2: -12.218301- 	Loss_total: -18.435717
# Train Epoch 19:iter100 - 	Loss1: -6.149713- 	Loss2: -12.186506- 	Loss_total: -18.336219
# Train Epoch 19:iter110 - 	Loss1: -6.375054- 	Loss2: -12.249721- 	Loss_total: -18.624774

# %%
# モデル分類のクラスターの結果を確認する

def test(model, device, train_loader):
    model.eval()

    # 結果を格納するリスト
    out_targs = []
    ref_targs = []
    cnt = 0

    with torch.no_grad():
        for data, target in test_loader:
            cnt += 1
            data = data.to(device)
            target = target.to(device)
            outputs, outputs_overclustering = model(data)

            # 分類結果をリストに追加
            out_targs.append(outputs.argmax(dim=1).cpu())
            ref_targs.append(target.cpu())

    # リストをひとまとめに
    out_targs = torch.cat(out_targs)
    ref_targs = torch.cat(ref_targs)

    return out_targs.numpy(), ref_targs.numpy()


out_targs, ref_targs = test(model_trained, device, train_loader)

# %%
import numpy as np
import scipy.stats as stats

# 混同行列（的な）を作る
matrix = np.zeros((10, 10))

# 縦に数字の0から9を、横に判定されたクラスの頻度表を作成
for i in range(len(out_targs)):
    row = ref_targs[i]
    col = out_targs[i]
    matrix[row][col] += 1

np.set_printoptions(suppress=True)
print(matrix)
# Out:
# [[ 975.    0.    0.    0.    1.    0.    0.    0.    2.    2.]
#  [   0.    7.    0. 1119.    0.    0.    3.    0.    1.    5.]
#  [   5. 1011.    4.    0.    3.    1.    0.    3.    1.    4.]
#  [   0.    3.    4.    0.    0.  980.    4.    4.    0.   15.]
#  [   0.    0.    1.    0.  941.    0.    0.   39.    0.    1.]
#  [   1.    0.    0.    0.    0.    3.  867.    0.    1.   20.]
#  [   2.    1.    0.    1.    2.    0.    1.    1.  946.    4.]
#  [   0.    4. 1002.    3.    0.    0.    1.   18.    0.    0.]
#  [   2.    4.    1.    0.    0.    0.    0.    5.    0.  962.]
#  [   4.    0.    2.    1.    3.   12.    5.  972.    0.   10.]]

# %%
# 全データ
total_num = matrix.sum().sum()
print(total_num)

# 各数字がきれいに各クラスに分かれている。
# 例えば数字の0はクラスの1番目に978個集まった。数字の9であれば、7番目に949個集まった。
# よって、最大のものを足していくと、正解の個数なので
correct_num_list = matrix.max(axis=0)
print(correct_num_list)
print(correct_num_list.sum())

print("正解率：", correct_num_list.sum()/total_num*100)
# Out:
# 10000.0
# [ 975. 1011. 1002. 1119.  941.  980.  867.  972.  946.  962.]
# 9775.0
# 正解率： 97.75

# %% [markdown]
# 以上。
